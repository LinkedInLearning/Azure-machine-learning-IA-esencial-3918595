# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "numbers":[1,2,3,4,5,6],
    "squares":[1,4,9,16,25,36]
}

df = pd.DataFrame(data)

print("DataFrame:")
df

df.plot(x="numbers", y="squares", kind="bar", title="Numbers & Squares")
plt.show()
# Out:
# DataFrame:
